# %%
idade_permitida = int(input("Digite a sua idade:"))
# professor vou tentar normalisar o texto foi pedido nao mais so pra lembrar da pratica 
def limpar_texto(raposta):
    resposta = texto.strip().lower()
    resposta= ''.join(
            letra for letra in unicodedata.normalize('NFD', resposta)
            if unicodedata.category(letra) != 'Mn'
    )
    return resposta

idade = int(input("Digite tua idade: ")
    if idade >= 12:
    resposta_do_ingresso = input("Voce esta com ingresso? ")
    resposta_do_ingresso = normalizar_resposta(resposta_do_ingresso)

    if resposta_do_ingresso in ["s", "sim"]:
        print("Entrada liberada! ")
    elif  resposta_do_ingresso in ["n", "nao"]:
        print("Por favor compre um ingresso! ")
    else: 
        print("Resposta invalida")
else: 
    print("Idade insuficiente")
# Out:
#   Cell In[1], line 3
#     def limpar_texto(raposta):
#     ^
# SyntaxError: invalid syntax
