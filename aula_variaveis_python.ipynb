# %%
var_1 = "Python"
print(f"Eu estou aprendendo ", var_1)
# Out:
# Eu estou aprendendo  Python

# %%
nome = "Maria"
cidade = "Recife" 
print(f"Meu nome é ", nome)
print(f"Eu moro em ", cidade)
# Out:
# Meu nome é  Maria
# Eu moro em  Recife

# %%
nome_do_aluno = input("Digite o nome do aluno: ")
idade_do_aluno = input("Digite a idade do aluno: ")
print(f"Meu nome é ", nome_do_aluno, "e tenho ", idade_do_aluno, "anos")
# Out:
# Digite o nome do aluno:  Thiago
# Digite a idade do aluno:  35
# Meu nome é  Thiago e tenho  35 anos

# %%
cidade = "Salvador"
estado = "BA" 
paiz = "Brasil" 
print(f"Eu moro em ", cidade,"- BA, ", paiz)
# Out:
# Eu moro em  Salvador - BA,  Brasil

# %%
nome = input("Qual o seu nome? ")
print(f"OLA  ", nome)
# Out:
# Qual o seu nome?  sgFAS
# O seu nome é  sgFAS

# %%
nome = input("Qual o seu nome? ")
cidade = input("Qual cidade onde voce mora? ") 
print(f"Olá, ", nome,"voce mora em", cidade)
